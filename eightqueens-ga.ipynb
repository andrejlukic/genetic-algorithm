# %% [markdown]
# # 8 Queens
#
# ### Introduction
#
# <figure>
# <img src="resources/eight_queens_moves.png", width=300 align="right">
#     <figcaption></figcaption>
# </figure>
#
# The [Eight Queens puzzle](https://en.wikipedia.org/wiki/Eight_queens_puzzle) is a famous puzzle that has been studied extensively in- and outside of computer science. It was first published in the chess magazine _Schach_ in 1848.
#
# The problem can be formulated as follows:
#
# _"Place 8 queens on a regular (8x8) chess board such that no queen attacks any other queen."_
#
# A queen in the game of chess can move horizontally, vertically, and diagonally. The puzzle can be solved by hand (and even [Carl Friedrich Gauss](https://en.wikipedia.org/wiki/Carl_Friedrich_Gauss) studied it back in 1850).

# %% [markdown]
# The EightQueensState class below, as well as the methods defined, should prove a helpful start for a Genetic Algorithms approach. However, you are welcome to change as little or as much of the code as is useful.

# %%
import numpy as np

class EightQueensState:
    """This class represents a board in the eight queens puzzle"""
    def __init__(self, n, state=None):
        """
        :param state: pass in a numpy array of integers to set the state, otherwise will be generated randomly
        :param n: only used if state is not provided, determines size of board (default: 8)
        """
        if state is None:
            self.n = n
            state = np.random.randint(0, n, n)
        else:
            self.n = len(state)
        
        self.state = state        
        self._fitness = ((self.n*(self.n-1))-self.cost())/2

    @staticmethod
    def copy_replace(state, i, x):
        """This creates a copy of the state (important as numpy arrays are mutable) with column i set to x"""
        new_state = state.copy()
        new_state[i] = x
        return new_state

    @staticmethod
    def range_missing(start, stop, missing):
        """
        This creates a list of numbers with a single value missing
        e.g. range_missing(0, 8, 2) -> [0, 1, 3, 4, 5, 6, 7]
        """
        return list(range(start, missing)) + list(range(missing + 1, stop))

    def cost(self):
        """Calculates the number of pairs attacking"""
        count = 0
        for i in range(len(self.state) - 1):
            # for each queen, look in columns to the right
            # add one to the count if there is another queen in the same row
            count += (self.state[i] == np.array(self.state[i + 1:])).sum()

            # add one to the count for each queen on the upper or lower diagonal
            upper_diagonal = self.state[i] + np.arange(1, self.n - i)
            lower_diagonal = self.state[i] - np.arange(1, self.n - i)
            count += (np.array(self.state[i + 1:]) == upper_diagonal).sum()
            count += (np.array(self.state[i + 1:]) == lower_diagonal).sum()
        return count
    
    def fitness(self):
        """Return the fitness valuation (n*(n-1)-cost)/2"""
        return self._fitness
    
    def neighbourhood(self):
        """This generates every state possible by changing a single queen position"""
        neighbourhood = []
        for column in range(self.n):
            for new_position in self.range_missing(0, self.n, self.state[column]):
                new_state = self.copy_replace(self.state, column, new_position)
                neighbourhood.append(EightQueensState(new_state))

        return neighbourhood
    
    def mutate(self):
        """Mutate a letter of the baby DNA and hope for the best"""
        new_state = self.state.copy()
        v = randint(0, self.n-1)
        new_state[v] = randint(0, self.n-1)
        return EightQueensState(self.n, state=new_state), v

    def random_neighbour(self):
        """Generates a single random neighbour state, useful for some algorithms"""
        column = np.random.choice(range(self.n))
        new_position = np.random.choice(self.range_missing(0, self.n, self.state[column]))
        new_state = self.copy_replace(self.state, column, new_position)
        return EightQueensState(new_state)

    def is_goal(self):
        return self.cost() == 0

    def __str__(self):
        if self.is_goal():
            return f"Goal state! {self.state}"
        else:
            return f"{self.state} cost {self.cost()}"

# %%
from random import random, randint, shuffle, choices

class EightQueensPopulation:
    """This class represents a generation of puzzle game states"""
    
    def __init__(self, queen_count, population=None, size=None, generation=0):
        """
        If no population is passed at init the population will be created based
        on the size parameter.
        
        :param state: pass in a list of EightQueensState objects
        """        
        if not population:
            self._pop=[]
            if size:
                for i in range(size):
                    self._pop.append(EightQueensState(queen_count))

        else:
            self._pop = population
        self._gen = generation
        self.n = queen_count
        self._log = []
    
    def print_state(self, dump_pop=False, dump_log=False):
        """
        Prints debug output
        
        :param dump_pop: prints the whole population
        :param dump_log: prints the step log including parents, mutations
        """
        avg_fit = sum([i.fitness() for i in self._pop])/len(self._pop)
        probs = self.probabilities()
        print("Generation {}, avg fit {}".format(self._gen, avg_fit))       
        if dump_pop:
            for i in range(len(self._pop)):
                print("{}, {}".format(self._pop[i], probs[i]*100))
        if dump_log:
            for t in self._log:
                if len(t) == 4:
                    print("{} + {} at {} = {}".format(t[0],t[1],t[2],t[3]))
                elif len(t)==1:
                    print("Mutated to {}".format(t[0]))
        
    def grow(self, i):
        """Adds DNA to the population"""
        self._pop.append(i)
    
    def size(self):
        """Returns the size of population"""
        return len(self._pop)
    
    @staticmethod
    def norm(data):
        return (data - np.min(data)) / (np.max(data) - np.min(data))
    
    def max_fitness(self):
        """Returns the maximum fitness score"""
        return (self.n*(self.n-1))/2
    
    def probabilities(self):    
        # fit_sum = sum([i.fitness() for i in self._pop])
        # normalized = EightQueensPopulation.norm(np.array([i.fitness()/fit_sum for i in self._pop])).tolist()        
        # return [(p, i) for p, i in zip(normalized, self._pop)]
        return [i.fitness()/self.max_fitness() for i in self._pop]
    
    def cull(self, candidates, cutoff=0.2):
        """Cull worst solutions out of population"""
        return [(p, i) for p,i in candidates if p >= cutoff]        
    
    def pick_n(self, culling = True, n=2):
        """Random weighted pick from the population"""
        
        return choices(self._pop, weights=[i.fitness() for i in self._pop], k=n)
    
    def log(self, t):
        self._log.append(t)

    def offspring(self, parents):
        """Create a new DNA by merging two parents' DNA codes at random point"""
        n = len(parents[0].state)
        inx = randint(0, n)
        left = parents[0].state.copy()[0:inx]
        right = parents[1].state.copy()[inx:n]
        return EightQueensState(self.n, state=np.concatenate([left,right])), inx

# %%
from random import random, randint, shuffle

N=8                  # number of queens
N_POPULATION=100     # size of population
P_MUTATION=0.03      # probability of mutation

def genetic_algo():

    gen_i = 0        # Generation count
    old_gen = EightQueensPopulation(N, size = N_POPULATION, generation=gen_i)

    not_found = True
    while not_found:        
        next_gen=EightQueensPopulation(N, generation=gen_i+1)

        for i in range(N_POPULATION):
            
            parents = old_gen.pick_n(culling=False)
            baby, inx = next_gen.offspring(parents)

            next_gen.log((parents[0], parents[1], inx, baby))
            
            if random() < P_MUTATION:
                baby, inx = baby.mutate()
                next_gen.log((baby, inx))                         

            if(next_gen.size() < old_gen.size()):
                next_gen.grow(baby)
            
            not_found = not baby.is_goal()
            
            if not not_found:
                # Found solution:
                print(baby)
                break
        old_gen=next_gen
        gen_i += 1  
        old_gen.print_state(dump_pop=False)        

genetic_algo()
# Out:
# Generation 1, avg fit 24.03
# Generation 2, avg fit 24.12
# Generation 3, avg fit 24.415
# Generation 4, avg fit 24.16
# Generation 5, avg fit 24.26
# Generation 6, avg fit 24.385
# Generation 7, avg fit 24.47
# Generation 8, avg fit 24.325
# Generation 9, avg fit 24.385
# Generation 10, avg fit 24.295
# Generation 11, avg fit 24.16
# Generation 12, avg fit 24.205
# Generation 13, avg fit 24.115
# Generation 14, avg fit 24.42
# Generation 15, avg fit 24.355
# Generation 16, avg fit 24.305
# Generation 17, avg fit 24.22
# Generation 18, avg fit 24.35
# Generation 19, avg fit 24.27
# Generation 20, avg fit 24.135
# Generation 21, avg fit 24.18
# Generation 22, avg fit 24.165
# Generation 23, avg fit 24.17
# Generation 24, avg fit 24.105
# Generation 25, avg fit 24.05
# Generation 26, avg fit 24.23
# Generation 27, avg fit 24.39
# Generation 28, avg fit 24.485
# Generation 29, avg fit 24.41
# Generation 30, avg fit 24.365
# Generation 31, avg fit 24.39
# Generation 32, avg fit 24.37
# Generation 33, avg fit 24.395
# Generation 34, avg fit 24.565
# Generation 35, avg fit 24.31
# Generation 36, avg fit 24.23
# Generation 37, avg fit 24.27
# Generation 38, avg fit 24.26
# Generation 39, avg fit 24.345
# Generation 40, avg fit 24.37
# Generation 41, avg fit 24.34
# Generation 42, avg fit 24.745
# Generation 43, avg fit 24.585
# Generation 44, avg fit 24.645
# Generation 45, avg fit 24.635
# Generation 46, avg fit 24.84
# Generation 47, avg fit 24.805
# Generation 48, avg fit 24.8
# Generation 49, avg fit 24.6
# Generation 50, avg fit 24.61
# Generation 51, avg fit 24.665
# Generation 52, avg fit 24.735
# Generation 53, avg fit 24.7
# Generation 54, avg fit 24.55
# Generation 55, avg fit 24.65
# Generation 56, avg fit 24.455
# Generation 57, avg fit 24.43
# Generation 58, avg fit 24.61
# Generation 59, avg fit 24.62
# Generation 60, avg fit 24.67
# Generation 61, avg fit 24.61
# Generation 62, avg fit 24.59
# Generation 63, avg fit 24.76
# Generation 64, avg fit 24.655
# Generation 65, avg fit 24.58
# Generation 66, avg fit 24.695
# Generation 67, avg fit 24.715
# Generation 68, avg fit 24.6
# Generation 69, avg fit 24.73
# Generation 70, avg fit 24.795
# Generation 71, avg fit 24.76
# Generation 72, avg fit 24.755
# Generation 73, avg fit 24.665
# Generation 74, avg fit 24.58
# Generation 75, avg fit 24.555
# Generation 76, avg fit 24.605
# Generation 77, avg fit 24.55
# Generation 78, avg fit 24.59
# Generation 79, avg fit 24.44
# Generation 80, avg fit 24.52
# Generation 81, avg fit 24.58
# Generation 82, avg fit 24.67
# Generation 83, avg fit 24.755
# Generation 84, avg fit 24.905
# Generation 85, avg fit 24.785
# Generation 86, avg fit 24.83
# Generation 87, avg fit 24.83
# Generation 88, avg fit 24.975
# Generation 89, avg fit 24.93
# Generation 90, avg fit 24.915
# Generation 91, avg fit 24.94
# Generation 92, avg fit 25.135
# Generation 93, avg fit 25.045
# Generation 94, avg fit 24.99
# Generation 95, avg fit 25.075
# Generation 96, avg fit 25.02
# Generation 97, avg fit 24.955
# Generation 98, avg fit 24.965
# Generation 99, avg fit 24.89
# Generation 100, avg fit 24.875
# Generation 101, avg fit 24.885
# Generation 102, avg fit 24.935
# Generation 103, avg fit 25.07
# Generation 104, avg fit 25.075
# Generation 105, avg fit 25.12
# Generation 106, avg fit 25.065
# Generation 107, avg fit 25.1
# Generation 108, avg fit 25.125
# Generation 109, avg fit 25.155
# Generation 110, avg fit 25.06
# Generation 111, avg fit 25.155
# Generation 112, avg fit 25.19
# Generation 113, avg fit 25.275
# Generation 114, avg fit 25.3
# Generation 115, avg fit 25.22
# Generation 116, avg fit 25.33
# Generation 117, avg fit 25.325
# Generation 118, avg fit 25.31
# Generation 119, avg fit 25.355
# Generation 120, avg fit 25.365
# Generation 121, avg fit 25.425
# Generation 122, avg fit 25.435
# Generation 123, avg fit 25.43
# Generation 124, avg fit 25.465
# Generation 125, avg fit 25.41
# Generation 126, avg fit 25.42
# Generation 127, avg fit 25.48
# Generation 128, avg fit 25.445
# Generation 129, avg fit 25.52
# Generation 130, avg fit 25.505
# Generation 131, avg fit 25.41
# Generation 132, avg fit 25.355
# Generation 133, avg fit 25.305
# Generation 134, avg fit 25.34
# Generation 135, avg fit 25.28
# Generation 136, avg fit 25.245
# Generation 137, avg fit 25.215
# Generation 138, avg fit 25.155
# Generation 139, avg fit 25.175
# Generation 140, avg fit 25.235
# Generation 141, avg fit 25.34
# Generation 142, avg fit 25.32
# Generation 143, avg fit 25.215
# Generation 144, avg fit 25.25
# Generation 145, avg fit 25.26
# Generation 146, avg fit 25.09
# Generation 147, avg fit 25.075
# Generation 148, avg fit 25.075
# Generation 149, avg fit 25.11
# Generation 150, avg fit 25.07
# Generation 151, avg fit 25.02
# Generation 152, avg fit 25.05
# Generation 153, avg fit 25.06
# Generation 154, avg fit 25.11
# Generation 155, avg fit 25.165
# Generation 156, avg fit 25.17
# Generation 157, avg fit 25.205
# Generation 158, avg fit 25.235
# Generation 159, avg fit 25.155
# Generation 160, avg fit 25.22
# Generation 161, avg fit 25.255
# Generation 162, avg fit 25.15
# Generation 163, avg fit 25.0
# Generation 164, avg fit 25.175
# Generation 165, avg fit 25.18
# Generation 166, avg fit 25.195
# Generation 167, avg fit 25.315
# Generation 168, avg fit 25.255
# Generation 169, avg fit 25.265
# Generation 170, avg fit 25.325
# Generation 171, avg fit 25.355
# Generation 172, avg fit 25.505
# Generation 173, avg fit 25.555
# Generation 174, avg fit 25.59
# Generation 175, avg fit 25.74
# Generation 176, avg fit 25.75
# Generation 177, avg fit 25.715
# Generation 178, avg fit 25.7
# Generation 179, avg fit 25.65
# Generation 180, avg fit 25.7
# Generation 181, avg fit 25.645
# Generation 182, avg fit 25.675
# Generation 183, avg fit 25.695
# Generation 184, avg fit 25.65
# Generation 185, avg fit 25.68
# Generation 186, avg fit 25.64
# Generation 187, avg fit 25.575
# Generation 188, avg fit 25.51
# Generation 189, avg fit 25.61
# Generation 190, avg fit 25.625
# Generation 191, avg fit 25.565
# Generation 192, avg fit 25.61
# Generation 193, avg fit 25.615
# Generation 194, avg fit 25.515
# Generation 195, avg fit 25.55
# Generation 196, avg fit 25.53
# Generation 197, avg fit 25.625
# Generation 198, avg fit 25.555
# Generation 199, avg fit 25.67
# Generation 200, avg fit 25.62
# Generation 201, avg fit 25.765
# Generation 202, avg fit 25.735
# Generation 203, avg fit 25.75
# Generation 204, avg fit 25.795
# Generation 205, avg fit 25.88
# Generation 206, avg fit 25.84
# Generation 207, avg fit 25.815
# Generation 208, avg fit 25.81
# Generation 209, avg fit 25.815
# Generation 210, avg fit 25.785
# Generation 211, avg fit 25.83
# Generation 212, avg fit 25.775
# Generation 213, avg fit 25.69
# Generation 214, avg fit 25.745
# Generation 215, avg fit 25.745
# Generation 216, avg fit 25.745
# Generation 217, avg fit 25.725
# Generation 218, avg fit 25.715
# Generation 219, avg fit 25.66
# Generation 220, avg fit 25.73
# Generation 221, avg fit 25.71
# Generation 222, avg fit 25.66
# Generation 223, avg fit 25.555
# Generation 224, avg fit 25.51
# Generation 225, avg fit 25.545
# Generation 226, avg fit 25.5
# Generation 227, avg fit 25.61
# Generation 228, avg fit 25.555
# Generation 229, avg fit 25.49
# Generation 230, avg fit 25.51
# Generation 231, avg fit 25.53
# Generation 232, avg fit 25.435
# Generation 233, avg fit 25.44
# Generation 234, avg fit 25.355
# Generation 235, avg fit 25.23
# Generation 236, avg fit 25.19
# Generation 237, avg fit 25.355
# Generation 238, avg fit 25.335
# Generation 239, avg fit 25.345
# Generation 240, avg fit 25.4
# Generation 241, avg fit 25.415
# Generation 242, avg fit 25.485
# Generation 243, avg fit 25.48
# Generation 244, avg fit 25.47
# Generation 245, avg fit 25.48
# Generation 246, avg fit 25.485
# Generation 247, avg fit 25.455
# Generation 248, avg fit 25.51
# Generation 249, avg fit 25.57
# Generation 250, avg fit 25.685
# Generation 251, avg fit 25.73
# Generation 252, avg fit 25.69
# Generation 253, avg fit 25.645
# Generation 254, avg fit 25.64
# Generation 255, avg fit 25.615
# Generation 256, avg fit 25.59
# Generation 257, avg fit 25.56
# Generation 258, avg fit 25.55
# Generation 259, avg fit 25.45
# Generation 260, avg fit 25.565
# Generation 261, avg fit 25.485
# Generation 262, avg fit 25.455
# Generation 263, avg fit 25.565
# Generation 264, avg fit 25.68
# Generation 265, avg fit 25.62
# Generation 266, avg fit 25.73
# Generation 267, avg fit 25.715
# Generation 268, avg fit 25.615
# Generation 269, avg fit 25.515
# Generation 270, avg fit 25.545
# Generation 271, avg fit 25.455
# Generation 272, avg fit 25.49
# Generation 273, avg fit 25.515
# Generation 274, avg fit 25.56
# Generation 275, avg fit 25.55
# Generation 276, avg fit 25.575
# Generation 277, avg fit 25.525
# Generation 278, avg fit 25.58
# Generation 279, avg fit 25.555
# Generation 280, avg fit 25.545
# Generation 281, avg fit 25.615
# Generation 282, avg fit 25.73
# Generation 283, avg fit 25.695
# Generation 284, avg fit 25.66
# Generation 285, avg fit 25.635
# Generation 286, avg fit 25.71
# Generation 287, avg fit 25.665
# Generation 288, avg fit 25.55
# Generation 289, avg fit 25.59
# Generation 290, avg fit 25.58
# Generation 291, avg fit 25.585
# Generation 292, avg fit 25.65
# Generation 293, avg fit 25.64
# Generation 294, avg fit 25.58
# Generation 295, avg fit 25.63
# Generation 296, avg fit 25.65
# Generation 297, avg fit 25.68
# Generation 298, avg fit 25.615
# Generation 299, avg fit 25.49
# Generation 300, avg fit 25.565
# Generation 301, avg fit 25.52
# Generation 302, avg fit 25.45
# Generation 303, avg fit 25.43
# Generation 304, avg fit 25.31
# Generation 305, avg fit 25.355
# Generation 306, avg fit 25.43
# Generation 307, avg fit 25.53
# Generation 308, avg fit 25.53
# Generation 309, avg fit 25.56
# Generation 310, avg fit 25.495
# Generation 311, avg fit 25.58
# Generation 312, avg fit 25.615
# Generation 313, avg fit 25.655
# Generation 314, avg fit 25.695
# Generation 315, avg fit 25.615
# Generation 316, avg fit 25.615
# Generation 317, avg fit 25.685
# Generation 318, avg fit 25.665
# Generation 319, avg fit 25.615
# Generation 320, avg fit 25.465
# Generation 321, avg fit 25.63
# Generation 322, avg fit 25.605
# Generation 323, avg fit 25.635
# Generation 324, avg fit 25.665
# Generation 325, avg fit 25.74
# Generation 326, avg fit 25.655
# Generation 327, avg fit 25.645
# Generation 328, avg fit 25.61
# Generation 329, avg fit 25.585
# Generation 330, avg fit 25.54
# Generation 331, avg fit 25.47
# Generation 332, avg fit 25.49
# Generation 333, avg fit 25.56
# Generation 334, avg fit 25.705
# Generation 335, avg fit 25.715
# Generation 336, avg fit 25.73
# Generation 337, avg fit 25.735
# Generation 338, avg fit 25.73
# Generation 339, avg fit 25.745
# Generation 340, avg fit 25.71
# Generation 341, avg fit 25.74
# Generation 342, avg fit 25.775
# Generation 343, avg fit 25.77
# Generation 344, avg fit 25.79
# Generation 345, avg fit 25.74
# Generation 346, avg fit 25.83
# Generation 347, avg fit 25.78
# Generation 348, avg fit 25.775
# Generation 349, avg fit 25.73
# Generation 350, avg fit 25.795
# Generation 351, avg fit 25.795
# Generation 352, avg fit 25.885
# Generation 353, avg fit 25.95
# Generation 354, avg fit 26.015
# Generation 355, avg fit 25.955
# Generation 356, avg fit 25.9
# Generation 357, avg fit 25.905
# Generation 358, avg fit 25.83
# Generation 359, avg fit 25.865
# Generation 360, avg fit 25.93
# Generation 361, avg fit 25.96
# Generation 362, avg fit 25.875
# Generation 363, avg fit 25.89
# Generation 364, avg fit 25.77
# Generation 365, avg fit 25.795
# Generation 366, avg fit 25.755
# Generation 367, avg fit 25.79
# Generation 368, avg fit 25.865
# Generation 369, avg fit 25.88
# Generation 370, avg fit 25.79
# Generation 371, avg fit 25.705
# Generation 372, avg fit 25.74
# Generation 373, avg fit 25.73
# Generation 374, avg fit 25.71
# Generation 375, avg fit 25.8
# Generation 376, avg fit 25.69
# Generation 377, avg fit 25.69
# Generation 378, avg fit 25.82
# Generation 379, avg fit 25.835
# Generation 380, avg fit 25.805
# Generation 381, avg fit 25.82
# Generation 382, avg fit 25.65
# Generation 383, avg fit 25.705
# Generation 384, avg fit 25.635
# Generation 385, avg fit 25.62
# Generation 386, avg fit 25.55
# Generation 387, avg fit 25.535
# Generation 388, avg fit 25.48
# Generation 389, avg fit 25.4
# Generation 390, avg fit 25.375
# Generation 391, avg fit 25.44
# Generation 392, avg fit 25.56
# Generation 393, avg fit 25.54
# Generation 394, avg fit 25.745
# Generation 395, avg fit 25.815
# Generation 396, avg fit 25.75
# Generation 397, avg fit 25.835
# Generation 398, avg fit 25.89
# Generation 399, avg fit 25.895
# Generation 400, avg fit 25.97
# Generation 401, avg fit 26.05
# Generation 402, avg fit 25.85
# Generation 403, avg fit 25.835
# Generation 404, avg fit 25.785
# Generation 405, avg fit 25.68
# Generation 406, avg fit 25.77
# Generation 407, avg fit 25.785
# Generation 408, avg fit 25.765
# Generation 409, avg fit 25.94
# Generation 410, avg fit 25.98
# Generation 411, avg fit 25.94
# Generation 412, avg fit 26.055
# Generation 413, avg fit 26.035
# Generation 414, avg fit 26.015
# Generation 415, avg fit 25.975
# Generation 416, avg fit 25.915
# Generation 417, avg fit 25.845
# Generation 418, avg fit 25.82
# Generation 419, avg fit 25.75
# Generation 420, avg fit 25.89
# Generation 421, avg fit 25.84
# Generation 422, avg fit 25.705
# Generation 423, avg fit 25.855
# Generation 424, avg fit 25.85
# Generation 425, avg fit 25.68
# Generation 426, avg fit 25.71
# Generation 427, avg fit 25.71
# Generation 428, avg fit 25.675
# Generation 429, avg fit 25.455
# Generation 430, avg fit 25.675
# Generation 431, avg fit 25.455
# Generation 432, avg fit 25.57
# Generation 433, avg fit 25.52
# Generation 434, avg fit 25.73
# Generation 435, avg fit 25.59
# Generation 436, avg fit 25.665
# Generation 437, avg fit 25.655
# Generation 438, avg fit 25.56
# Generation 439, avg fit 25.725
# Generation 440, avg fit 25.765
# Generation 441, avg fit 25.665
# Generation 442, avg fit 25.75
# Generation 443, avg fit 25.72
# Generation 444, avg fit 25.795
# Generation 445, avg fit 25.73
# Generation 446, avg fit 25.63
# Generation 447, avg fit 25.745
# Generation 448, avg fit 25.86
# Generation 449, avg fit 25.81
# Generation 450, avg fit 25.725
# Generation 451, avg fit 25.62
# Generation 452, avg fit 25.62
# Generation 453, avg fit 25.73
# Generation 454, avg fit 25.685
# Generation 455, avg fit 25.685
# Generation 456, avg fit 25.67
# Generation 457, avg fit 25.515
# Generation 458, avg fit 25.41
# Generation 459, avg fit 25.37
# Generation 460, avg fit 25.51
# Generation 461, avg fit 25.725
# Generation 462, avg fit 25.705
# Generation 463, avg fit 25.7
# Generation 464, avg fit 25.675
# Generation 465, avg fit 25.545
# Generation 466, avg fit 25.65
# Generation 467, avg fit 25.655
# Generation 468, avg fit 25.685
# Generation 469, avg fit 25.625
# Generation 470, avg fit 25.53
# Generation 471, avg fit 25.48
# Generation 472, avg fit 25.515
# Generation 473, avg fit 25.525
# Generation 474, avg fit 25.55
# Generation 475, avg fit 25.56
# Generation 476, avg fit 25.4
# Generation 477, avg fit 25.34
# Generation 478, avg fit 25.45
# Generation 479, avg fit 25.415
# Generation 480, avg fit 25.36
# Generation 481, avg fit 25.365
# Generation 482, avg fit 25.3
# Generation 483, avg fit 25.355
# Generation 484, avg fit 25.39
# Generation 485, avg fit 25.465
# Generation 486, avg fit 25.405
# Generation 487, avg fit 25.535
# Generation 488, avg fit 25.465
# Generation 489, avg fit 25.45
# Generation 490, avg fit 25.395
# Generation 491, avg fit 25.23
# Generation 492, avg fit 25.115
# Generation 493, avg fit 25.28
# Generation 494, avg fit 25.29
# Generation 495, avg fit 25.3
# Generation 496, avg fit 25.375
# Generation 497, avg fit 25.575
# Generation 498, avg fit 25.67
# Generation 499, avg fit 25.68
# Generation 500, avg fit 25.69
# Generation 501, avg fit 25.59
# Generation 502, avg fit 25.6
# Generation 503, avg fit 25.53
# Generation 504, avg fit 25.46
# Generation 505, avg fit 25.45
# Generation 506, avg fit 25.475
# Generation 507, avg fit 25.405
# Generation 508, avg fit 25.515
# Generation 509, avg fit 25.46
# Generation 510, avg fit 25.455
# Generation 511, avg fit 25.66
# Generation 512, avg fit 25.665
# Generation 513, avg fit 25.53
# Generation 514, avg fit 25.57
# Generation 515, avg fit 25.6
# Generation 516, avg fit 25.695
# Generation 517, avg fit 25.785
# Generation 518, avg fit 25.79
# Generation 519, avg fit 25.97
# Generation 520, avg fit 25.83
# Generation 521, avg fit 25.735
# Generation 522, avg fit 25.755
# Generation 523, avg fit 25.815
# Generation 524, avg fit 25.715
# Generation 525, avg fit 25.855
# Generation 526, avg fit 25.945
# Generation 527, avg fit 25.87
# Generation 528, avg fit 25.775
# Generation 529, avg fit 25.685
# Generation 530, avg fit 25.83
# Generation 531, avg fit 25.875
# Generation 532, avg fit 26.03
# Generation 533, avg fit 26.09
# Generation 534, avg fit 26.11
# Generation 535, avg fit 26.185
# Generation 536, avg fit 26.125
# Generation 537, avg fit 26.075
# Generation 538, avg fit 26.2
# Generation 539, avg fit 26.2
# Generation 540, avg fit 26.15
# Generation 541, avg fit 26.11
# Generation 542, avg fit 26.155
# Generation 543, avg fit 26.165
# Generation 544, avg fit 26.21
# Generation 545, avg fit 26.16
# Generation 546, avg fit 26.075
# Generation 547, avg fit 26.065
# Generation 548, avg fit 25.98
# Generation 549, avg fit 25.9
# Generation 550, avg fit 25.905
# Generation 551, avg fit 25.895
# Generation 552, avg fit 25.92
# Generation 553, avg fit 25.98
# Generation 554, avg fit 25.98
# Generation 555, avg fit 26.015
# Generation 556, avg fit 25.99
# Generation 557, avg fit 26.015
# Generation 558, avg fit 26.055
# Generation 559, avg fit 25.96
# Generation 560, avg fit 25.975
# Generation 561, avg fit 25.995
# Generation 562, avg fit 25.785
# Generation 563, avg fit 25.835
# Generation 564, avg fit 25.875
# Generation 565, avg fit 25.76
# Generation 566, avg fit 25.7
# Generation 567, avg fit 25.795
# Generation 568, avg fit 25.79
# Generation 569, avg fit 25.72
# Generation 570, avg fit 25.76
# Generation 571, avg fit 25.705
# Generation 572, avg fit 25.74
# Generation 573, avg fit 25.785
# Generation 574, avg fit 25.785
# Generation 575, avg fit 25.725
# Generation 576, avg fit 25.795
# Generation 577, avg fit 25.81
# Generation 578, avg fit 25.92
# Generation 579, avg fit 26.015
# Generation 580, avg fit 26.055
# Generation 581, avg fit 26.0
# Generation 582, avg fit 26.08
# Generation 583, avg fit 26.125
# Generation 584, avg fit 26.13
# Generation 585, avg fit 26.13
# Generation 586, avg fit 26.125
# Generation 587, avg fit 26.125
# Generation 588, avg fit 26.07
# Generation 589, avg fit 26.005
# Generation 590, avg fit 25.92
# Generation 591, avg fit 25.83
# Generation 592, avg fit 25.74
# Generation 593, avg fit 25.755
# Generation 594, avg fit 25.86
# Generation 595, avg fit 25.85
# Generation 596, avg fit 25.885
# Generation 597, avg fit 25.8
# Generation 598, avg fit 25.855
# Generation 599, avg fit 25.825
# Generation 600, avg fit 25.805
# Generation 601, avg fit 25.745
# Generation 602, avg fit 25.705
# Generation 603, avg fit 25.775
# Generation 604, avg fit 25.755
# Generation 605, avg fit 25.8
# Generation 606, avg fit 25.86
# Generation 607, avg fit 25.815
# Generation 608, avg fit 25.815
# Generation 609, avg fit 25.93
# Generation 610, avg fit 25.915
# Generation 611, avg fit 25.9
# Generation 612, avg fit 25.9
# Generation 613, avg fit 26.025
# Generation 614, avg fit 26.065
# Generation 615, avg fit 25.995
# Generation 616, avg fit 26.055
# Generation 617, avg fit 26.05
# Generation 618, avg fit 26.06
# Generation 619, avg fit 26.055
# Generation 620, avg fit 26.045
# Generation 621, avg fit 26.045
# Generation 622, avg fit 26.205
# Generation 623, avg fit 26.185
# Generation 624, avg fit 26.16
# Generation 625, avg fit 26.17
# Generation 626, avg fit 26.1
# Generation 627, avg fit 26.075
# Generation 628, avg fit 26.045
# Generation 629, avg fit 26.0
# Generation 630, avg fit 26.075
# Generation 631, avg fit 26.07
# Generation 632, avg fit 25.99
# Generation 633, avg fit 25.99
# Generation 634, avg fit 25.935
# Generation 635, avg fit 25.94
# Generation 636, avg fit 25.925
# Generation 637, avg fit 25.9
# Generation 638, avg fit 25.905
# Generation 639, avg fit 25.775
# Generation 640, avg fit 25.83
# Generation 641, avg fit 25.735
# Generation 642, avg fit 25.64
# Generation 643, avg fit 25.595
# Generation 644, avg fit 25.615
# Generation 645, avg fit 25.645
# Generation 646, avg fit 25.63
# Generation 647, avg fit 25.745
# Generation 648, avg fit 25.84
# Generation 649, avg fit 25.865
# Generation 650, avg fit 25.805
# Generation 651, avg fit 25.79
# Generation 652, avg fit 25.79
# Generation 653, avg fit 25.74
# Generation 654, avg fit 25.91
# Generation 655, avg fit 26.025
# Generation 656, avg fit 26.005
# Generation 657, avg fit 26.06
# Generation 658, avg fit 25.945
# Generation 659, avg fit 25.83
# Generation 660, avg fit 25.82
# Generation 661, avg fit 25.825
# Generation 662, avg fit 25.84
# Generation 663, avg fit 25.805
# Generation 664, avg fit 25.93
# Generation 665, avg fit 25.955
# Generation 666, avg fit 26.015
# Generation 667, avg fit 26.03
# Generation 668, avg fit 25.95
# Generation 669, avg fit 25.93
# Generation 670, avg fit 25.92
# Generation 671, avg fit 26.03
# Generation 672, avg fit 26.065
# Generation 673, avg fit 25.965
# Generation 674, avg fit 25.995
# Generation 675, avg fit 26.035
# Generation 676, avg fit 26.09
# Generation 677, avg fit 26.11
# Generation 678, avg fit 26.19
# Generation 679, avg fit 26.215
# Generation 680, avg fit 26.165
# Generation 681, avg fit 26.08
# Generation 682, avg fit 26.13
# Generation 683, avg fit 26.135
# Generation 684, avg fit 26.08
# Generation 685, avg fit 25.98
# Generation 686, avg fit 26.02
# Generation 687, avg fit 26.005
# Generation 688, avg fit 26.0
# Generation 689, avg fit 25.97
# Generation 690, avg fit 26.025
# Generation 691, avg fit 25.96
# Generation 692, avg fit 25.98
# Generation 693, avg fit 25.965
# Generation 694, avg fit 25.975
# Generation 695, avg fit 26.0
# Generation 696, avg fit 25.875
# Generation 697, avg fit 25.935
# Generation 698, avg fit 25.95
# Generation 699, avg fit 25.97
# Generation 700, avg fit 25.96
# Generation 701, avg fit 25.855
# Generation 702, avg fit 25.83
# Generation 703, avg fit 25.855
# Generation 704, avg fit 25.86
# Generation 705, avg fit 25.9
# Generation 706, avg fit 25.855
# Generation 707, avg fit 25.935
# Generation 708, avg fit 25.87
# Generation 709, avg fit 25.905
# Generation 710, avg fit 25.94
# Generation 711, avg fit 25.97
# Generation 712, avg fit 25.91
# Generation 713, avg fit 25.88
# Generation 714, avg fit 25.865
# Generation 715, avg fit 25.915
# Generation 716, avg fit 25.855
# Generation 717, avg fit 25.81
# Generation 718, avg fit 25.91
# Generation 719, avg fit 25.835
# Generation 720, avg fit 25.945
# Generation 721, avg fit 26.01
# Generation 722, avg fit 26.025
# Generation 723, avg fit 26.035
# Generation 724, avg fit 26.055
# Generation 725, avg fit 26.07
# Generation 726, avg fit 26.115
# Generation 727, avg fit 26.07
# Generation 728, avg fit 26.02
# Generation 729, avg fit 26.115
# Generation 730, avg fit 26.09
# Generation 731, avg fit 26.05
# Generation 732, avg fit 25.96
# Generation 733, avg fit 25.885
# Generation 734, avg fit 25.88
# Generation 735, avg fit 25.88
# Generation 736, avg fit 25.95
# Generation 737, avg fit 25.9
# Generation 738, avg fit 25.82
# Generation 739, avg fit 25.87
# Generation 740, avg fit 25.84
# Generation 741, avg fit 25.785
# Generation 742, avg fit 25.715
# Generation 743, avg fit 25.71
# Generation 744, avg fit 25.665
# Generation 745, avg fit 25.68
# Generation 746, avg fit 25.655
# Generation 747, avg fit 25.72
# Generation 748, avg fit 25.815
# Generation 749, avg fit 25.83
# Generation 750, avg fit 25.805
# Generation 751, avg fit 25.85
# Generation 752, avg fit 25.845
# Generation 753, avg fit 25.745
# Generation 754, avg fit 25.805
# Generation 755, avg fit 25.85
# Generation 756, avg fit 25.9
# Generation 757, avg fit 25.885
# Generation 758, avg fit 25.74
# Generation 759, avg fit 25.715
# Generation 760, avg fit 25.76
# Generation 761, avg fit 25.865
# Generation 762, avg fit 25.905
# Generation 763, avg fit 25.95
# Generation 764, avg fit 26.09
# Generation 765, avg fit 26.095
# Generation 766, avg fit 26.07
# Generation 767, avg fit 26.06
# Generation 768, avg fit 25.94
# Generation 769, avg fit 25.975
# Generation 770, avg fit 25.985
# Generation 771, avg fit 26.09
# Generation 772, avg fit 25.985
# Generation 773, avg fit 26.065
# Generation 774, avg fit 25.975
# Generation 775, avg fit 25.975
# Generation 776, avg fit 26.155
# Generation 777, avg fit 26.15
# Generation 778, avg fit 26.205
# Generation 779, avg fit 26.185
# Generation 780, avg fit 26.215
# Generation 781, avg fit 26.17
# Generation 782, avg fit 26.12
# Generation 783, avg fit 26.205
# Generation 784, avg fit 26.235
# Generation 785, avg fit 26.215
# Generation 786, avg fit 26.195
# Generation 787, avg fit 26.315
# Generation 788, avg fit 26.32
# Generation 789, avg fit 26.315
# Generation 790, avg fit 26.3
# Generation 791, avg fit 26.235
# Generation 792, avg fit 26.315
# Generation 793, avg fit 26.33
# Generation 794, avg fit 26.36
# Generation 795, avg fit 26.335
# Generation 796, avg fit 26.42
# Generation 797, avg fit 26.37
# Generation 798, avg fit 26.24
# Generation 799, avg fit 26.325
# Generation 800, avg fit 26.4
# Generation 801, avg fit 26.465
# Generation 802, avg fit 26.475
# Generation 803, avg fit 26.475
# Generation 804, avg fit 26.535
# Generation 805, avg fit 26.51
# Generation 806, avg fit 26.475
# Generation 807, avg fit 26.385
# Generation 808, avg fit 26.265
# Generation 809, avg fit 26.25
# Generation 810, avg fit 26.335
# Generation 811, avg fit 26.34
# Generation 812, avg fit 26.21
# Generation 813, avg fit 26.25
# Generation 814, avg fit 26.27
# Generation 815, avg fit 26.2
# Generation 816, avg fit 26.275
# Generation 817, avg fit 26.19
# Generation 818, avg fit 26.255
# Generation 819, avg fit 26.225
# Generation 820, avg fit 26.32
# Generation 821, avg fit 26.39
# Generation 822, avg fit 26.395
# Generation 823, avg fit 26.305
# Generation 824, avg fit 26.345
# Generation 825, avg fit 26.49
# Generation 826, avg fit 26.525
# Generation 827, avg fit 26.44
# Generation 828, avg fit 26.385
# Generation 829, avg fit 26.345
# Generation 830, avg fit 26.385
# Generation 831, avg fit 26.285
# Generation 832, avg fit 26.21
# Generation 833, avg fit 26.225
# Generation 834, avg fit 26.24
# Generation 835, avg fit 26.21
# Generation 836, avg fit 26.165
# Generation 837, avg fit 26.16
# Generation 838, avg fit 26.12
# Generation 839, avg fit 26.195
# Generation 840, avg fit 26.255
# Generation 841, avg fit 26.24
# Generation 842, avg fit 26.145
# Generation 843, avg fit 26.23
# Generation 844, avg fit 26.32
# Generation 845, avg fit 26.325
# Generation 846, avg fit 26.25
# Generation 847, avg fit 26.22
# Generation 848, avg fit 26.195
# Generation 849, avg fit 26.08
# Generation 850, avg fit 26.14
# Generation 851, avg fit 26.145
# Generation 852, avg fit 25.94
# Generation 853, avg fit 25.99
# Generation 854, avg fit 26.075
# Generation 855, avg fit 26.085
# Generation 856, avg fit 26.1
# Generation 857, avg fit 26.11
# Generation 858, avg fit 26.05
# Generation 859, avg fit 26.035
# Generation 860, avg fit 26.05
# Generation 861, avg fit 26.095
# Generation 862, avg fit 26.115
# Generation 863, avg fit 26.18
# Generation 864, avg fit 26.205
# Generation 865, avg fit 26.24
# Generation 866, avg fit 26.235
# Generation 867, avg fit 26.12
# Generation 868, avg fit 26.085
# Generation 869, avg fit 26.07
# Generation 870, avg fit 26.215
# Generation 871, avg fit 26.11
# Generation 872, avg fit 25.96
# Generation 873, avg fit 26.025
# Generation 874, avg fit 26.085
# Generation 875, avg fit 26.205
# Generation 876, avg fit 26.265
# Generation 877, avg fit 26.19
# Generation 878, avg fit 26.16
# Generation 879, avg fit 26.255
# Generation 880, avg fit 26.205
# Generation 881, avg fit 26.1
# Generation 882, avg fit 26.1
# Generation 883, avg fit 26.2
# Generation 884, avg fit 26.13
# Generation 885, avg fit 26.165
# Generation 886, avg fit 26.2
# Generation 887, avg fit 26.205
# Generation 888, avg fit 26.205
# Generation 889, avg fit 26.19
# Generation 890, avg fit 26.175
# Generation 891, avg fit 26.26
# Generation 892, avg fit 26.22
# Generation 893, avg fit 26.255
# Generation 894, avg fit 26.27
# Generation 895, avg fit 26.28
# Generation 896, avg fit 26.245
# Generation 897, avg fit 26.06
# Generation 898, avg fit 26.195
# Generation 899, avg fit 26.095
# Generation 900, avg fit 26.115
# Generation 901, avg fit 26.195
# Generation 902, avg fit 26.215
# Generation 903, avg fit 26.155
# Generation 904, avg fit 26.135
# Generation 905, avg fit 26.265
# Generation 906, avg fit 26.29
# Generation 907, avg fit 26.295
# Generation 908, avg fit 26.41
# Generation 909, avg fit 26.43
# Generation 910, avg fit 26.465
# Generation 911, avg fit 26.54
# Generation 912, avg fit 26.555
# Generation 913, avg fit 26.48
# Generation 914, avg fit 26.635
# Generation 915, avg fit 26.605
# Generation 916, avg fit 26.53
# Generation 917, avg fit 26.505
# Generation 918, avg fit 26.47
# Generation 919, avg fit 26.42
# Generation 920, avg fit 26.29
# Generation 921, avg fit 26.285
# Generation 922, avg fit 26.25
# Generation 923, avg fit 26.075
# Generation 924, avg fit 26.095
# Generation 925, avg fit 26.185
# Generation 926, avg fit 26.08
# Generation 927, avg fit 25.995
# Generation 928, avg fit 25.86
# Generation 929, avg fit 25.855
# Generation 930, avg fit 25.925
# Generation 931, avg fit 26.045
# Generation 932, avg fit 26.09
# Generation 933, avg fit 26.22
# Generation 934, avg fit 26.175
# Generation 935, avg fit 26.125
# Generation 936, avg fit 26.115
# Generation 937, avg fit 26.01
# Generation 938, avg fit 26.085
# Generation 939, avg fit 26.165
# Generation 940, avg fit 26.05
# Generation 941, avg fit 26.13
# Generation 942, avg fit 26.175
# Generation 943, avg fit 26.08
# Generation 944, avg fit 26.085
# Generation 945, avg fit 26.07
# Generation 946, avg fit 26.06
# Generation 947, avg fit 26.125
# Generation 948, avg fit 26.26
# Generation 949, avg fit 26.15
# Generation 950, avg fit 26.005
# Generation 951, avg fit 25.87
# Generation 952, avg fit 25.99
# Generation 953, avg fit 25.97
# Generation 954, avg fit 25.94
# Generation 955, avg fit 25.985
# Generation 956, avg fit 25.93
# Generation 957, avg fit 26.05
# Generation 958, avg fit 26.2
# Generation 959, avg fit 26.08
# Generation 960, avg fit 26.165
# Generation 961, avg fit 26.17
# Generation 962, avg fit 26.245
# Generation 963, avg fit 26.165
# Generation 964, avg fit 26.17
# Generation 965, avg fit 26.19
# Generation 966, avg fit 26.245
# Goal state! [3 0 4 7 1 6 2 5]
# Generation 967, avg fit 26.431818181818183
